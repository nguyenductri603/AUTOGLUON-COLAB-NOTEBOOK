# %%
from autogluon.tabular import TabularDataset, TabularPredictor

data_root = '' #train set
train_data = TabularDataset(data_root)
subsample_size = 5000
train_data = train_data.sample(n=subsample_size, random_state=0)
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3873     -117.95     33.84                18.0       3418.0           815.0
# 3625     -117.92     34.08                36.0       1479.0           251.0
# 3028     -117.80     33.83                17.0       2971.0           350.0
# 13814    -122.01     36.98                47.0       2403.0           517.0
# 15398    -122.30     38.25                18.0       3548.0           880.0
#
#        population  households  median_income  median_house_value
# 3873       1961.0       773.0         3.6500            171400.0
# 3625        741.0       245.0         4.2986            189600.0
# 3028       1180.0       346.0        11.1228            500001.0
# 13814      1144.0       455.0         2.5954            229400.0
# 15398      1476.0       699.0         3.7188            163400.0

# %%
from autogluon.common import space

nn_options = {  # specifies non-default hyperparameter values for neural network models
    'num_epochs': 20,  # number of training epochs (controls training time of NN models)
    'learning_rate': space.Real(1e-4, 1e-2, default=5e-4, log=True),  # learning rate used in training (real-valued hyperparameter searched on log-scale)
    'activation': space.Categorical('relu', 'sigmoid', 'softmax'),  # activation function used in NN (categorical hyperparameter, default = first entry)
    'dropout_prob': space.Real(0.0, 0.5, default=0.1),  # dropout probability (real-valued hyperparameter)
}

gbm_options = {  # specifies non-default hyperparameter values for lightGBM gradient boosted trees
    'num_boost_round': 100,  # number of boosting rounds (controls training time of GBM models)
    'num_leaves': space.Int(lower=26, upper=66, default=36),  # number of leaves in trees (integer hyperparameter)
}

hyperparameters = {  # hyperparameters of each model type
                   'GBM': gbm_options,
                   'NN_TORCH': nn_options,  # NOTE: comment this line out if you get errors on Mac OSX
                  }  # When these keys are missing from hyperparameters dict, no models of that type are trained

time_limit = 2*60  # train various models for ~2 min
num_trials = 5  # try at most 5 different hyperparameter configurations for each type of model
search_strategy = 'auto'  # to tune hyperparameters using random search routine with a local scheduler

hyperparameter_tune_kwargs = {  # HPO is not performed unless hyperparameter_tune_kwargs is specified
    'num_trials': num_trials,
    'scheduler' : 'local',
    'searcher': search_strategy,
}  # Refer to TabularPredictor.fit docstring for all valid values

label = 'median_house_value'
predictor = TabularPredictor(label=label).fit(
    train_data,
    time_limit=time_limit,
    hyperparameters=hyperparameters,
    hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20260105_062314"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.12.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Oct  2 10:42:05 UTC 2025
# CPU Count:          2
# Pytorch Version:    2.9.0+cu126
# CUDA Version:       12.6
# GPU Memory:         GPU 0: 14.74/14.74 GB
# Total GPU Memory:   Free: 14.74 GB, Allocated: 0.00 GB, Total: 14.74 GB
# GPU Count:          1
# Memory Avail:       11.08 GB / 12.67 GB (87.5%)
# Disk Space Avail:   73.25 GB / 112.64 GB (65.0%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme'  : New in v1.5: The state-of-the-art for tabular data. Massively better than 'best' on datasets <100000 samples by using new Tabular Foundation Models (TFMs) meta-learned on https://tabarena.ai: TabPFNv2, TabICL, Mitra, TabDPT, and TabM. Requires a GPU and `pip install autogluon.tabular[tabarena]` to install TabPFN, TabICL, and TabDPT.
# 	presets='best'     : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='best_v150': New in v1.5: Better quality than 'best' and 5x+ faster to train. Give it a try!
# 	presets='high'     : Strong accuracy with fast inference speed.
# 	presets='high_v150': New in v1.5: Better quality than 'high' and 5x+ faster to train. Give it a try!
# 	presets='good'     : Good accuracy with very fast inference speed.
# 	presets='medium'   : Fast training time, ideal for initial prototyping.
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "/content/AutogluonModels/ag-20260105_062314"
# Train Data Rows:    5000
# Train Data Columns: 8
# Label Column:       median_house_value
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (500001.0, 14999.0, 205817.6626, 115060.59154)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11338.72 MB
# 	Train Data (Original)  Memory Usage: 0.31 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', ...]
# 	0.0s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.31 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 4000, Val Rows: 1000
# User-specified model hyperparameters to be fit:
# {
# 	'GBM': [{'num_boost_round': 100, 'num_leaves': Int: lower=26, upper=66}],
# 	'NN_TORCH': [{'num_epochs': 20, 'learning_rate': Real: lower=0.0001, upper=0.01, 'activation': Categorical['relu', 'sigmoid', 'softmax'], 'dropout_prob': Real: lower=0.0, upper=0.5}],
# }
# Fitting 2 L1 models, fit_strategy="sequential" ...
# Hyperparameter tuning model: LightGBM ... Tuning model for up to 53.97s of the 119.93s of remaining time.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Fitted model: LightGBM/T1 ...
# 	-50048.1599	 = Validation score   (-root_mean_squared_error)
# 	4.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM/T2 ...
# 	-47490.6641	 = Validation score   (-root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM/T3 ...
# 	-51094.1781	 = Validation score   (-root_mean_squared_error)
# 	0.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM/T4 ...
# 	-84104.927	 = Validation score   (-root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM/T5 ...
# 	-52339.9218	 = Validation score   (-root_mean_squared_error)
# 	0.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Hyperparameter tuning model: NeuralNetTorch ... Tuning model for up to 53.97s of the 113.85s of remaining time.
# /usr/local/lib/python3.12/dist-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# +---------------------------------------------------+
# | Configuration for experiment     NeuralNetTorch   |
# +---------------------------------------------------+
# | Search algorithm                 SearchGenerator  |
# | Scheduler                        FIFOScheduler    |
# | Number of trials                 5                |
# +---------------------------------------------------+
#
# View detailed results here: /content/AutogluonModels/ag-20260105_062314/models/NeuralNetTorch
# Fitted model: NeuralNetTorch/64930efc ...
# 	-57988.3636	 = Validation score   (-root_mean_squared_error)
# 	10.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: NeuralNetTorch/b38cdec2 ...
# 	-67042.541	 = Validation score   (-root_mean_squared_error)
# 	7.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.93s of the 52.10s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=2, gpus=0, mem=0.0/9.9 GB
# 	Ensemble Weights: {'LightGBM/T2': 0.96, 'NeuralNetTorch/64930efc': 0.04}
# 	-47471.3612	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 67.94s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 54775.2 rows/s (1000 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20260105_062314")

# %%
test_data = TabularDataset('') #test set
test_data.head()
# Out:
# Loaded data from: /content/sample_data/california_housing_test.csv | Columns = 9 / 9 | Rows = 3000 -> 3000
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
y_pred = predictor.predict(test_data)
y_pred.head()
# Out:
# 0    395918.968750
# 1    212150.593750
# 2    268234.312500
# 3    331088.156250
# 4     78526.492188
# Name: median_house_value, dtype: float32

# %%
predictor.evaluate(test_data)
# Out:
# {'root_mean_squared_error': np.float64(-51670.06907583184),
#  'mean_squared_error': -2669796038.301234,
#  'mean_absolute_error': -35026.23275065104,
#  'r2': 0.7912884515829814,
#  'pearsonr': 0.8900083776308401,
#  'median_absolute_error': np.float64(-23637.9765625)}

# %%
predictor.leaderboard(test_data)
# Out:
#                      model    score_test     score_val  \
# 0      WeightedEnsemble_L2 -51670.069076 -47471.361183
# 1              LightGBM/T2 -51802.879053 -47490.664075
# 2              LightGBM/T1 -52705.691131 -50048.159914
# 3              LightGBM/T3 -53866.755078 -51094.178133
# 4              LightGBM/T5 -54516.245957 -52339.921847
# 5  NeuralNetTorch/64930efc -60101.409864 -57988.363564
# 6  NeuralNetTorch/b38cdec2 -71417.764961 -67042.540962
# 7              LightGBM/T4 -83741.134250 -84104.926966
#
#                eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0  root_mean_squared_error        0.045430       0.018256  10.741539
# 1  root_mean_squared_error        0.023213       0.007410   0.282549
# 2  root_mean_squared_error        0.028675       0.008758   4.685450
# 3  root_mean_squared_error        0.034233       0.010963   0.316599
# 4  root_mean_squared_error        0.027055       0.008381   0.320348
# 5  root_mean_squared_error        0.020250       0.010412  10.446845
# 6  root_mean_squared_error        0.031784       0.013480   7.816179
# 7  root_mean_squared_error        0.017832       0.005462   0.280407
#
#    pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                 0.001967                0.000434           0.012145
# 1                 0.023213                0.007410           0.282549
# 2                 0.028675                0.008758           4.685450
# 3                 0.034233                0.010963           0.316599
# 4                 0.027055                0.008381           0.320348
# 5                 0.020250                0.010412          10.446845
# 6                 0.031784                0.013480           7.816179
# 7                 0.017832                0.005462           0.280407
#
#    stack_level  can_infer  fit_order
# 0            2       True          8
# 1            1       True          2
# 2            1       True          1
# 3            1       True          3
# 4            1       True          5
# 5            1       True          6
# 6            1       True          7
# 7            1       True          4

# %%
predictor = TabularPredictor.load(predictor.path)

# %%
# Will create a minimal artifact for deployment.
predictor.clone_for_deployment(path='prod_model_dir')
# Load the optimized predictor and persist models in mem.
predictor_opt = TabularPredictor.load('prod_model_dir')
predictor_opt.persist()
predictions = predictor_opt.predict(test_data)
